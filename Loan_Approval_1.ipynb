# %%
# !pip install pandas
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/loan_approval_data.csv')

# %%
data.head()
# Out:
#       id   age  income home_ownership  emplyment_length      loan_intent  \
# 0  35437  21.0   12000            OWN                 0        EDUCATION
# 1  53756  21.0   13200            OWN                 2        EDUCATION
# 2  42205  23.0    9600           RENT                 5          MEDICAL
# 3  19180  40.0  182004           RENT                 3        EDUCATION
# 4  28072  40.0   90000       MORTGAGE                 3  HOMEIMPROVEMENT
#
#    loan_amount  loan_interest_rate  loan_income_ratio payment_default_on_file  \
# 0        15000                6.99               0.12                       N
# 1        25000               16.77               0.19                       Y
# 2        30000               12.42               0.31                       N
# 3        35000                8.00               0.19                       N
# 4        35000               12.42               0.39                       N
#
# ...

# %%
list(data.columns)
# Out:
# ['id',
#  'age',
#  'income',
#  'home_ownership',
#  'emplyment_length',
#  'loan_intent',
#  'loan_amount',
#  'loan_interest_rate',
#  'loan_income_ratio',
#  'payment_default_on_file',
#  'credit_history_length',
#  'loan_approval_status',
#  'max_allowed_loan']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       58645 non-null  int64
#  1   age                      58639 non-null  float64
#  2   income                   58645 non-null  int64
#  3   home_ownership           58645 non-null  object
#  4   emplyment_length         58645 non-null  int64
#  5   loan_intent              58645 non-null  object
#  6   loan_amount              58645 non-null  int64
#  7   loan_interest_rate       58634 non-null  float64
#  8   loan_income_ratio        58645 non-null  float64
#  9   payment_default_on_file  58640 non-null  object
#  10  credit_history_length    58645 non-null  int64
#  11  loan_approval_status     58645 non-null  int64
#  12  max_allowed_loan         58645 non-null  int64
# dtypes: float64(3), int64(7), object(3)
# memory usage: 5.8+ MB

# %%
data.isnull().sum()
# Out:
# id                          0
# age                         6
# income                      0
# home_ownership              0
# emplyment_length            0
# loan_intent                 0
# loan_amount                 0
# loan_interest_rate         11
# loan_income_ratio           0
# payment_default_on_file     5
# credit_history_length       0
# loan_approval_status        0
# max_allowed_loan            0
# dtype: int64

# %%
data[data['age'].isnull()]
# Out:
#           id  age  income home_ownership  emplyment_length      loan_intent  \
# 7461   44039  NaN   30288           RENT                17         PERSONAL
# 10456   2224  NaN   36000           RENT                 5        EDUCATION
# 14459   2214  NaN   45432       MORTGAGE                 3         PERSONAL
# 29241   2255  NaN   65000       MORTGAGE                 5        EDUCATION
# 49227  44016  NaN   75000       MORTGAGE                 1        EDUCATION
# 49298  44113  NaN   70000           RENT                 3  HOMEIMPROVEMENT
#
#        loan_amount  loan_interest_rate  loan_income_ratio  \
# 7461          5000               14.74               0.17
# 10456        10000               10.37               0.28
# 14459        10000                9.88               0.22
# 29241         6000                7.49               0.09
# 49227        12500                6.03               0.16
# 49298         4000               13.85               0.06
#
# ...

# %%
data['age'].max()
# Out:
# 123.0

# %%
data['age'].nlargest(5)
# Out:
# 39792    123.0
# 54600     84.0
# 56540     84.0
# 8727      80.0
# 8728      80.0
# Name: age, dtype: float64

# %%
data[data['age']==123]
# Out:
#           id    age  income home_ownership  emplyment_length loan_intent  \
# 39792  47336  123.0   36000       MORTGAGE                 7    PERSONAL
#
#        loan_amount  loan_interest_rate  loan_income_ratio  \
# 39792         6700               10.75               0.18
#
#       payment_default_on_file  credit_history_length  loan_approval_status  \
# 39792                       N                      4                     0
#
#        max_allowed_loan
# 39792             81860
